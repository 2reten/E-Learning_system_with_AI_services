# %%
import pandas as pd
import tensorflow as tf
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import load_img, img_to_array
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.image import pad_to_bounding_box
from tensorflow.image import central_crop
from tensorflow.image import resize
from PIL import Image

# %%
# 이미지 불러오기
target_size = (64, 64)

images = []
for i in range(1, 12001):
    try:
        img = load_img(f"3_train/{i}.png", target_size=target_size)  # 이미지 크기 조정
        image_arr = img_to_array(img)
        images.append(image_arr)
    except FileNotFoundError:
        print(f"파일 {i}.png를 찾을 수 없습니다.")

# %%
# 이후에 np.array 변환과 정규화 수행
images = np.array(images) / 255.0

# %%
images.shape
# Out:
# (12000, 64, 64, 3)

# %%
pip install tensorflow_addons
# Out:
# Requirement already satisfied: tensorflow_addons in c:\users\user\anaconda3\lib\site-packages (0.22.0)
# Requirement already satisfied: typeguard<3.0.0,>=2.7 in c:\users\user\anaconda3\lib\site-packages (from tensorflow_addons) (2.13.3)
# Requirement already satisfied: packaging in c:\users\user\anaconda3\lib\site-packages (from tensorflow_addons) (23.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.preprocessing.image import load_img, img_to_array
import tensorflow as tf
import tensorflow_addons as tfa
import math
# Out:
# C:\Users\user\anaconda3\Lib\site-packages\tensorflow_addons\utils\tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(

# %%
import tensorflow as tf
import math
import tensorflow_addons as tfa

augmented_images = []

for image in images:
    # 1.Original Image
    augmented_images.append(image)

    # 2.Random Rotation within ±30 degrees
    rotation_degree = tf.random.uniform([], minval=-30, maxval=30, dtype=tf.float32)
    rotation_radian = rotation_degree * math.pi / 180
    rotated_tensor = tfa.image.rotate(image, rotation_radian)
    augmented_images.append(rotated_tensor.numpy())

    # 3.Random Brightness Adjustment
    brightness_tensor = tf.image.random_brightness(image, max_delta=0.5)
    augmented_images.append(brightness_tensor.numpy())

    # 4.Random Contrast Adjustment
    contrast_tensor = tf.image.random_contrast(image, lower=0.2, upper=1.8)
    augmented_images.append(contrast_tensor.numpy())

    # 5.Random Saturation Adjustment
    saturation_tensor = tf.image.random_saturation(image, lower=0.5, upper=1.5)
    augmented_images.append(saturation_tensor.numpy())

    # 6.Random Zoom
    zoom_tensor = tf.keras.preprocessing.image.random_zoom(image, zoom_range=(0.8, 1.2), row_axis=0, col_axis=1, channel_axis=2)
    augmented_images.append(zoom_tensor)

    # 7.Random Shear
    shear_tensor = tf.keras.preprocessing.image.random_shear(image, intensity=0.2, row_axis=0, col_axis=1, channel_axis=2)
    augmented_images.append(shear_tensor)

    # 8.Random Width Shift
    width_shift_tensor = tf.keras.preprocessing.image.random_shift(image, wrg=0.2, hrg=0, row_axis=0, col_axis=1, channel_axis=2)
    augmented_images.append(width_shift_tensor)

    # 9.Random Height Shift
    height_shift_tensor = tf.keras.preprocessing.image.random_shift(image, wrg=0, hrg=0.2, row_axis=0, col_axis=1, channel_axis=2)
    augmented_images.append(height_shift_tensor)

# Now, augmented_images list contains 5 original transformations plus 4 new transformations for each image.

# %%
len(augmented_images)
# Out:
# 108000

# %%
# 레이블준비
# 각 레이블에 대해 400개의 이미지가 있다고 가정하고 레이블 생성
# 원본 라벨링 데이터
# 0부터 5까지의 숫자를 각각 2000번씩 반복
original_labels = np.repeat(np.arange(0, 6), 2000)
labels = np.repeat(original_labels, 9)

# %%
len(labels)
# Out:
# 108000

# %%
# 이미지와 레이블을 섞어서 훈련 데이터와 검증 데이터로 분할
train_x, val_x, train_y, val_y = train_test_split(
    augmented_images, labels, test_size=0.2, shuffle=True, random_state=42)

# %%
# 타겟 데이터 정규화
num_classes=6

train_y = to_categorical(train_y, num_classes=num_classes)  # 원-핫 인코딩
val_y = to_categorical(val_y, num_classes=num_classes)

# %%
import numpy as np

train_x = np.array(train_x)
train_y = np.array(train_y)
val_x = np.array(val_x)
val_y = np.array(val_y)

print("train_x shape:", train_x.shape)
print("train_y shape:", train_y.shape)
print("val_x shape:", val_x.shape)
print("val_y shape:", val_y.shape)
# Out:
# train_x shape: (86400, 64, 64, 3)
# train_y shape: (86400, 6)
# val_x shape: (21600, 64, 64, 3)
# val_y shape: (21600, 6)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPooling2D, BatchNormalization, LeakyReLU
from tensorflow.keras.callbacks import ModelCheckpoint,EarlyStopping,ReduceLROnPlateau
from tensorflow.keras.datasets import mnist
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.optimizers import Adam

# %%
num_classes = 6
model = Sequential()

# 첫 번째 컨볼루션 블록
model.add(Conv2D(32, (3, 3), input_shape=(64, 64, 3)))
model.add(BatchNormalization())
model.add(LeakyReLU(alpha=0.1))
model.add(MaxPooling2D((2, 2)))
model.add(Dropout(0.25))

# 두 번째 컨볼루션 블록
model.add(Conv2D(64, (3, 3)))
model.add(BatchNormalization())
model.add(LeakyReLU(alpha=0.1))
model.add(MaxPooling2D((2, 2)))
model.add(Dropout(0.25))

# 세 번째 컨볼루션 블록
model.add(Conv2D(128, (3, 3)))
model.add(BatchNormalization())
model.add(LeakyReLU(alpha=0.1))
model.add(MaxPooling2D((2, 2)))
model.add(Dropout(0.25))

# 플래튼 및 완전 연결 레이어
model.add(Flatten())
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(num_classes, activation='softmax'))

# Early Stopping, Model Checkpoint, ReduceLROnPlateau
early_stopping = EarlyStopping(monitor='val_loss', patience=5)
model_checkpoint = ModelCheckpoint('emotion_model.h5', save_best_only=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, min_lr=0.00001)

# %%
# 모델 컴파일
model.compile(optimizer=Adam(learning_rate=0.00001), loss='categorical_crossentropy', metrics=['accuracy'])

# 모델 훈련
history = model.fit(
    train_x, 
    train_y, 
    validation_data=(val_x, val_y),
    epochs=100,
    batch_size=64,  # You can change the number 32 to whatever batch size you prefer
    callbacks=[early_stopping, model_checkpoint]
)
# Out:
# Epoch 1/100
# 1350/1350 [==============================] - 215s 159ms/step - loss: 1.8673 - accuracy: 0.2774 - val_loss: 1.5541 - val_accuracy: 0.4300
# Epoch 2/100
# C:\Users\user\anaconda3\Lib\site-packages\keras\src\engine\training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 1350/1350 [==============================] - 209s 155ms/step - loss: 1.5090 - accuracy: 0.4076 - val_loss: 1.2564 - val_accuracy: 0.5594
# Epoch 3/100
# 1350/1350 [==============================] - 212s 157ms/step - loss: 1.2962 - accuracy: 0.5018 - val_loss: 0.9908 - val_accuracy: 0.6710
# Epoch 4/100
# 1350/1350 [==============================] - 212s 157ms/step - loss: 1.1067 - accuracy: 0.5812 - val_loss: 0.8030 - val_accuracy: 0.7387
# Epoch 5/100
# 1350/1350 [==============================] - 213s 157ms/step - loss: 0.9591 - accuracy: 0.6405 - val_loss: 0.6692 - val_accuracy: 0.7879
# Epoch 6/100
# 1350/1350 [==============================] - 209s 155ms/step - loss: 0.8503 - accuracy: 0.6855 - val_loss: 0.5683 - val_accuracy: 0.8255
# Epoch 7/100
# 1350/1350 [==============================] - 211s 156ms/step - loss: 0.7618 - accuracy: 0.7198 - val_loss: 0.5052 - val_accuracy: 0.8446
# Epoch 8/100
# 1350/1350 [==============================] - 205s 152ms/step - loss: 0.6908 - accuracy: 0.7494 - val_loss: 0.4475 - val_accuracy: 0.8638
# Epoch 9/100
# 1350/1350 [==============================] - 201s 149ms/step - loss: 0.6297 - accuracy: 0.7719 - val_loss: 0.4064 - val_accuracy: 0.8729
# Epoch 10/100
# 1350/1350 [==============================] - 201s 149ms/step - loss: 0.5849 - accuracy: 0.7899 - val_loss: 0.3693 - val_accuracy: 0.8851
# Epoch 11/100
# 1350/1350 [==============================] - 206s 153ms/step - loss: 0.5432 - accuracy: 0.8044 - val_loss: 0.3430 - val_accuracy: 0.8951
# Epoch 12/100
# 1350/1350 [==============================] - 205s 152ms/step - loss: 0.5057 - accuracy: 0.8185 - val_loss: 0.3189 - val_accuracy: 0.9017
# Epoch 13/100
# 1350/1350 [==============================] - 206s 152ms/step - loss: 0.4753 - accuracy: 0.8302 - val_loss: 0.2913 - val_accuracy: 0.9093
# Epoch 14/100
# 1350/1350 [==============================] - 206s 153ms/step - loss: 0.4466 - accuracy: 0.8409 - val_loss: 0.2772 - val_accuracy: 0.9146
# Epoch 15/100
# 1350/1350 [==============================] - 209s 155ms/step - loss: 0.4214 - accuracy: 0.8495 - val_loss: 0.2527 - val_accuracy: 0.9245
# Epoch 16/100
# 1350/1350 [==============================] - 210s 156ms/step - loss: 0.3995 - accuracy: 0.8601 - val_loss: 0.2373 - val_accuracy: 0.9294
# Epoch 17/100
# 1350/1350 [==============================] - 210s 156ms/step - loss: 0.3766 - accuracy: 0.8673 - val_loss: 0.2270 - val_accuracy: 0.9324
# Epoch 18/100
# 1350/1350 [==============================] - 211s 156ms/step - loss: 0.3618 - accuracy: 0.8719 - val_loss: 0.2097 - val_accuracy: 0.9402
# Epoch 19/100
# 1350/1350 [==============================] - 213s 158ms/step - loss: 0.3442 - accuracy: 0.8796 - val_loss: 0.2031 - val_accuracy: 0.9406
# Epoch 20/100
# 1350/1350 [==============================] - 213s 158ms/step - loss: 0.3286 - accuracy: 0.8857 - val_loss: 0.1900 - val_accuracy: 0.9457
# Epoch 21/100
# 1350/1350 [==============================] - 213s 158ms/step - loss: 0.3141 - accuracy: 0.8906 - val_loss: 0.1781 - val_accuracy: 0.9490
# Epoch 22/100
# 1350/1350 [==============================] - 213s 158ms/step - loss: 0.3020 - accuracy: 0.8944 - val_loss: 0.1686 - val_accuracy: 0.9526
# Epoch 23/100
# 1350/1350 [==============================] - 214s 159ms/step - loss: 0.2877 - accuracy: 0.9002 - val_loss: 0.1616 - val_accuracy: 0.9536
# Epoch 24/100
# 1350/1350 [==============================] - 215s 159ms/step - loss: 0.2779 - accuracy: 0.9034 - val_loss: 0.1509 - val_accuracy: 0.9579
# Epoch 25/100
# 1350/1350 [==============================] - 224s 166ms/step - loss: 0.2718 - accuracy: 0.9063 - val_loss: 0.1458 - val_accuracy: 0.9590
# Epoch 26/100
# 1350/1350 [==============================] - 216s 160ms/step - loss: 0.2584 - accuracy: 0.9107 - val_loss: 0.1416 - val_accuracy: 0.9604
# Epoch 27/100
# 1350/1350 [==============================] - 223s 165ms/step - loss: 0.2507 - accuracy: 0.9133 - val_loss: 0.1335 - val_accuracy: 0.9635
# Epoch 28/100
# 1350/1350 [==============================] - 226s 167ms/step - loss: 0.2409 - accuracy: 0.9172 - val_loss: 0.1268 - val_accuracy: 0.9644
# Epoch 29/100
# 1350/1350 [==============================] - 228s 169ms/step - loss: 0.2300 - accuracy: 0.9214 - val_loss: 0.1226 - val_accuracy: 0.9655
# Epoch 30/100
# 1350/1350 [==============================] - 228s 169ms/step - loss: 0.2240 - accuracy: 0.9234 - val_loss: 0.1177 - val_accuracy: 0.9673
# Epoch 31/100
# 1350/1350 [==============================] - 229s 170ms/step - loss: 0.2168 - accuracy: 0.9263 - val_loss: 0.1132 - val_accuracy: 0.9684
# Epoch 32/100
# 1350/1350 [==============================] - 229s 170ms/step - loss: 0.2117 - accuracy: 0.9276 - val_loss: 0.1063 - val_accuracy: 0.9713
# Epoch 33/100
# 1350/1350 [==============================] - 230s 170ms/step - loss: 0.2036 - accuracy: 0.9309 - val_loss: 0.1057 - val_accuracy: 0.9702
# Epoch 34/100
# 1350/1350 [==============================] - 230s 170ms/step - loss: 0.1986 - accuracy: 0.9318 - val_loss: 0.1001 - val_accuracy: 0.9719
# Epoch 35/100
# 1350/1350 [==============================] - 230s 170ms/step - loss: 0.1910 - accuracy: 0.9343 - val_loss: 0.1012 - val_accuracy: 0.9709
# Epoch 36/100
# 1350/1350 [==============================] - 229s 170ms/step - loss: 0.1867 - accuracy: 0.9358 - val_loss: 0.0934 - val_accuracy: 0.9742
# Epoch 37/100
# 1350/1350 [==============================] - 226s 167ms/step - loss: 0.1810 - accuracy: 0.9386 - val_loss: 0.0886 - val_accuracy: 0.9752
# Epoch 38/100
# 1350/1350 [==============================] - 224s 166ms/step - loss: 0.1802 - accuracy: 0.9392 - val_loss: 0.0874 - val_accuracy: 0.9752
# Epoch 39/100
# 1350/1350 [==============================] - 226s 167ms/step - loss: 0.1720 - accuracy: 0.9416 - val_loss: 0.0848 - val_accuracy: 0.9760
# Epoch 40/100
# 1350/1350 [==============================] - 225s 167ms/step - loss: 0.1707 - accuracy: 0.9426 - val_loss: 0.0814 - val_accuracy: 0.9769
# Epoch 41/100
# 1350/1350 [==============================] - 225s 167ms/step - loss: 0.1627 - accuracy: 0.9451 - val_loss: 0.0796 - val_accuracy: 0.9777
# Epoch 42/100
# 1350/1350 [==============================] - 224s 166ms/step - loss: 0.1609 - accuracy: 0.9456 - val_loss: 0.0785 - val_accuracy: 0.9772
# Epoch 43/100
# 1350/1350 [==============================] - 225s 166ms/step - loss: 0.1565 - accuracy: 0.9477 - val_loss: 0.0750 - val_accuracy: 0.9788
# Epoch 44/100
# 1350/1350 [==============================] - 224s 166ms/step - loss: 0.1515 - accuracy: 0.9487 - val_loss: 0.0709 - val_accuracy: 0.9801
# Epoch 45/100
# 1350/1350 [==============================] - 222s 165ms/step - loss: 0.1492 - accuracy: 0.9493 - val_loss: 0.0707 - val_accuracy: 0.9806
# Epoch 46/100
# 1350/1350 [==============================] - 223s 165ms/step - loss: 0.1470 - accuracy: 0.9510 - val_loss: 0.0676 - val_accuracy: 0.9803
# Epoch 47/100
# 1350/1350 [==============================] - 222s 164ms/step - loss: 0.1398 - accuracy: 0.9523 - val_loss: 0.0671 - val_accuracy: 0.9806
# Epoch 48/100
# 1350/1350 [==============================] - 221s 163ms/step - loss: 0.1404 - accuracy: 0.9528 - val_loss: 0.0653 - val_accuracy: 0.9813
# Epoch 49/100
# 1350/1350 [==============================] - 221s 164ms/step - loss: 0.1373 - accuracy: 0.9537 - val_loss: 0.0625 - val_accuracy: 0.9820
# Epoch 50/100
# 1350/1350 [==============================] - 220s 163ms/step - loss: 0.1335 - accuracy: 0.9543 - val_loss: 0.0599 - val_accuracy: 0.9831
# Epoch 51/100
# 1350/1350 [==============================] - 222s 164ms/step - loss: 0.1301 - accuracy: 0.9558 - val_loss: 0.0584 - val_accuracy: 0.9833
# Epoch 52/100
# 1350/1350 [==============================] - 216s 160ms/step - loss: 0.1277 - accuracy: 0.9569 - val_loss: 0.0589 - val_accuracy: 0.9831
# Epoch 53/100
# 1350/1350 [==============================] - 211s 156ms/step - loss: 0.1271 - accuracy: 0.9570 - val_loss: 0.0557 - val_accuracy: 0.9841
# Epoch 54/100
# 1350/1350 [==============================] - 211s 157ms/step - loss: 0.1228 - accuracy: 0.9587 - val_loss: 0.0559 - val_accuracy: 0.9838
# Epoch 55/100
# 1350/1350 [==============================] - 213s 157ms/step - loss: 0.1195 - accuracy: 0.9593 - val_loss: 0.0558 - val_accuracy: 0.9836
# Epoch 56/100
# 1350/1350 [==============================] - 211s 156ms/step - loss: 0.1174 - accuracy: 0.9604 - val_loss: 0.0524 - val_accuracy: 0.9851
# Epoch 57/100
# 1350/1350 [==============================] - 211s 156ms/step - loss: 0.1157 - accuracy: 0.9610 - val_loss: 0.0508 - val_accuracy: 0.9852
# Epoch 58/100
# 1350/1350 [==============================] - 211s 156ms/step - loss: 0.1149 - accuracy: 0.9611 - val_loss: 0.0511 - val_accuracy: 0.9854
# Epoch 59/100
# 1350/1350 [==============================] - 211s 156ms/step - loss: 0.1121 - accuracy: 0.9620 - val_loss: 0.0506 - val_accuracy: 0.9854
# Epoch 60/100
# 1350/1350 [==============================] - 211s 157ms/step - loss: 0.1090 - accuracy: 0.9630 - val_loss: 0.0484 - val_accuracy: 0.9861
# Epoch 61/100
# 1350/1350 [==============================] - 212s 157ms/step - loss: 0.1081 - accuracy: 0.9636 - val_loss: 0.0465 - val_accuracy: 0.9867
# Epoch 62/100
# 1350/1350 [==============================] - 211s 157ms/step - loss: 0.1047 - accuracy: 0.9647 - val_loss: 0.0462 - val_accuracy: 0.9867
# Epoch 63/100
# 1350/1350 [==============================] - 213s 158ms/step - loss: 0.1053 - accuracy: 0.9648 - val_loss: 0.0455 - val_accuracy: 0.9866
# Epoch 64/100
# 1350/1350 [==============================] - 218s 161ms/step - loss: 0.1028 - accuracy: 0.9655 - val_loss: 0.0459 - val_accuracy: 0.9867
# Epoch 65/100
# 1350/1350 [==============================] - 216s 160ms/step - loss: 0.0990 - accuracy: 0.9670 - val_loss: 0.0439 - val_accuracy: 0.9872
# Epoch 66/100
# 1350/1350 [==============================] - 216s 160ms/step - loss: 0.0979 - accuracy: 0.9673 - val_loss: 0.0426 - val_accuracy: 0.9876
# Epoch 67/100
# 1350/1350 [==============================] - 215s 159ms/step - loss: 0.0980 - accuracy: 0.9675 - val_loss: 0.0421 - val_accuracy: 0.9881
# Epoch 68/100
# 1350/1350 [==============================] - 215s 159ms/step - loss: 0.0961 - accuracy: 0.9679 - val_loss: 0.0416 - val_accuracy: 0.9880
# Epoch 69/100
# 1350/1350 [==============================] - 215s 159ms/step - loss: 0.0927 - accuracy: 0.9686 - val_loss: 0.0406 - val_accuracy: 0.9885
# Epoch 70/100
# 1350/1350 [==============================] - 215s 160ms/step - loss: 0.0920 - accuracy: 0.9691 - val_loss: 0.0399 - val_accuracy: 0.9887
# Epoch 71/100
# 1350/1350 [==============================] - 214s 159ms/step - loss: 0.0917 - accuracy: 0.9697 - val_loss: 0.0383 - val_accuracy: 0.9894
# Epoch 72/100
# 1350/1350 [==============================] - 214s 159ms/step - loss: 0.0870 - accuracy: 0.9701 - val_loss: 0.0377 - val_accuracy: 0.9890
# Epoch 73/100
# 1350/1350 [==============================] - 215s 159ms/step - loss: 0.0870 - accuracy: 0.9705 - val_loss: 0.0381 - val_accuracy: 0.9890
# Epoch 74/100
# 1350/1350 [==============================] - 214s 159ms/step - loss: 0.0877 - accuracy: 0.9701 - val_loss: 0.0361 - val_accuracy: 0.9900
# Epoch 75/100
# 1350/1350 [==============================] - 214s 159ms/step - loss: 0.0840 - accuracy: 0.9720 - val_loss: 0.0370 - val_accuracy: 0.9897
# Epoch 76/100
# 1350/1350 [==============================] - 214s 159ms/step - loss: 0.0841 - accuracy: 0.9718 - val_loss: 0.0358 - val_accuracy: 0.9899
# Epoch 77/100
# 1350/1350 [==============================] - 214s 159ms/step - loss: 0.0835 - accuracy: 0.9716 - val_loss: 0.0350 - val_accuracy: 0.9896
# Epoch 78/100
# 1350/1350 [==============================] - 214s 159ms/step - loss: 0.0792 - accuracy: 0.9735 - val_loss: 0.0355 - val_accuracy: 0.9897
# Epoch 79/100
# 1350/1350 [==============================] - 214s 158ms/step - loss: 0.0812 - accuracy: 0.9727 - val_loss: 0.0344 - val_accuracy: 0.9903
# Epoch 80/100
# 1350/1350 [==============================] - 215s 159ms/step - loss: 0.0790 - accuracy: 0.9733 - val_loss: 0.0334 - val_accuracy: 0.9909
# Epoch 81/100
# 1350/1350 [==============================] - 213s 158ms/step - loss: 0.0799 - accuracy: 0.9731 - val_loss: 0.0342 - val_accuracy: 0.9901
# Epoch 82/100
# 1350/1350 [==============================] - 214s 159ms/step - loss: 0.0772 - accuracy: 0.9741 - val_loss: 0.0327 - val_accuracy: 0.9904
# Epoch 83/100
# 1350/1350 [==============================] - 214s 159ms/step - loss: 0.0750 - accuracy: 0.9748 - val_loss: 0.0325 - val_accuracy: 0.9907
# Epoch 84/100
# 1350/1350 [==============================] - 214s 158ms/step - loss: 0.0755 - accuracy: 0.9746 - val_loss: 0.0318 - val_accuracy: 0.9909
# Epoch 85/100
# 1350/1350 [==============================] - 214s 159ms/step - loss: 0.0745 - accuracy: 0.9744 - val_loss: 0.0314 - val_accuracy: 0.9916
# Epoch 86/100
# 1350/1350 [==============================] - 215s 159ms/step - loss: 0.0714 - accuracy: 0.9758 - val_loss: 0.0300 - val_accuracy: 0.9910
# Epoch 87/100
# 1350/1350 [==============================] - 215s 159ms/step - loss: 0.0727 - accuracy: 0.9754 - val_loss: 0.0293 - val_accuracy: 0.9922
# Epoch 88/100
# 1350/1350 [==============================] - 215s 159ms/step - loss: 0.0707 - accuracy: 0.9763 - val_loss: 0.0301 - val_accuracy: 0.9913
# Epoch 89/100
# 1350/1350 [==============================] - 215s 160ms/step - loss: 0.0691 - accuracy: 0.9767 - val_loss: 0.0291 - val_accuracy: 0.9916
# Epoch 90/100
# 1350/1350 [==============================] - 215s 159ms/step - loss: 0.0684 - accuracy: 0.9763 - val_loss: 0.0293 - val_accuracy: 0.9919
# Epoch 91/100
# 1350/1350 [==============================] - 215s 159ms/step - loss: 0.0679 - accuracy: 0.9767 - val_loss: 0.0291 - val_accuracy: 0.9918
# Epoch 92/100
# 1350/1350 [==============================] - 215s 160ms/step - loss: 0.0679 - accuracy: 0.9768 - val_loss: 0.0292 - val_accuracy: 0.9916
# Epoch 93/100
# 1350/1350 [==============================] - 217s 160ms/step - loss: 0.0664 - accuracy: 0.9776 - val_loss: 0.0290 - val_accuracy: 0.9914
# Epoch 94/100
# 1350/1350 [==============================] - 221s 164ms/step - loss: 0.0665 - accuracy: 0.9775 - val_loss: 0.0270 - val_accuracy: 0.9929
# Epoch 95/100
# 1350/1350 [==============================] - 223s 165ms/step - loss: 0.0646 - accuracy: 0.9779 - val_loss: 0.0268 - val_accuracy: 0.9930
# Epoch 96/100
# 1350/1350 [==============================] - 222s 164ms/step - loss: 0.0636 - accuracy: 0.9784 - val_loss: 0.0270 - val_accuracy: 0.9928
# Epoch 97/100
# 1350/1350 [==============================] - 219s 162ms/step - loss: 0.0639 - accuracy: 0.9785 - val_loss: 0.0279 - val_accuracy: 0.9920
# Epoch 98/100
# 1350/1350 [==============================] - 219s 162ms/step - loss: 0.0621 - accuracy: 0.9791 - val_loss: 0.0280 - val_accuracy: 0.9919
# Epoch 99/100
# 1350/1350 [==============================] - 220s 163ms/step - loss: 0.0617 - accuracy: 0.9788 - val_loss: 0.0269 - val_accuracy: 0.9923
# Epoch 100/100
# 1350/1350 [==============================] - 221s 164ms/step - loss: 0.0617 - accuracy: 0.9795 - val_loss: 0.0258 - val_accuracy: 0.9927

# %%
import matplotlib.pyplot as plt

# 정확도 그래프
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)  # 1행 2열의 첫 번째 그래프
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

# 손실 그래프
plt.subplot(1, 2, 2)  # 1행 2열의 두 번째 그래프
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.show()

# %%
# 모델 평가
loss, accuracy = model.evaluate(val_x, val_y)
print(f"Loss: {loss}, Accuracy: {accuracy}")
# Out:
# 675/675 [==============================] - 12s 17ms/step - loss: 0.0258 - accuracy: 0.9927
# Loss: 0.025757113471627235, Accuracy: 0.9927314519882202

# %%
pred_y=model.predict(val_x)
predicted_classes = np.argmax(pred_y, axis=1)
predicted_classes
# Out:
# 675/675 [==============================] - 12s 17ms/step
# array([2, 0, 2, ..., 2, 5, 1], dtype=int64)

# %%
model = tf.keras.models.load_model('emotion_model.h5')

# %%
pip install opencv-python-headless
# Out:
# Requirement already satisfied: opencv-python-headless in c:\users\user\anaconda3\lib\site-packages (4.8.1.78)
# Requirement already satisfied: numpy>=1.21.2 in c:\users\user\anaconda3\lib\site-packages (from opencv-python-headless) (1.24.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
import tkinter as tk
from PIL import Image, ImageTk
import cv2
import numpy as np
import tensorflow as tf
import time
import os

# %%
import pandas as pd
from tensorflow.keras.preprocessing import image
import numpy as np
from tensorflow.image import pad_to_bounding_box
from tensorflow.image import central_crop
from tensorflow.image import resize
from PIL import Image
from tensorflow import keras
from tensorflow.keras.preprocessing.image import load_img, img_to_array
import tkinter as tk
from PIL import Image, ImageTk
import cv2
import numpy as np
import tensorflow as tf
import time
import os
import json
import time
from collections import Counter
from datetime import datetime

# %%
# 웹캠을 활용한 감정분석
class FaceRecognitionApp:
    def __init__(self, window, window_title, model):
        self.emotions_df= pd.DataFrame(columns=['Timestamp','Predicted_Emotion' ])
        self.window = window
        self.window.title(window_title)
        self.model = model
        self.video_source = 0
        self.vid = cv2.VideoCapture(self.video_source)
        
        
        if not self.vid.isOpened():
            raise ValueError("Unable to open video source", self.video_source)
        self.canvas = tk.Label(window, width=640, height=480)
        self.canvas.pack()
        self.face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
        self.window.bind("<space>", self.on_close)
        self.update()
        self.window.mainloop()
        
      
    def predict_emotion(self, face_img):
        try:
            resized_img = cv2.resize(face_img, (64, 64))
            filename = f"image_{int(time.time())}.png"
            filepath = f"images/{filename}"
            cv2.imwrite(filepath, resized_img)
            img = load_img(filepath)
            img_array = img_to_array(img) / 255.0
            img_array = np.expand_dims(img_array, axis=0)
            predictions = self.model.predict(img_array)                    
            class_index = np.argmax(predictions[0])
            emotions = ["Surprise", "Sad", "Happy", "Angry", "Neutral", "Confident"]
            
            predicted_emotion = emotions[class_index]
            current_time = datetime.now().strftime('%Y-%m-%d %H:%M:%S')
                      
            new_data = {'Timestamp': current_time, 'Predicted_Emotion': predicted_emotion}
            self.emotions_df.loc[len(self.emotions_df)] = [current_time, predicted_emotion]
            print(predicted_emotion)
            return predicted_emotion

        except Exception as e:
            print(f"Error in predict_emotion: {e}")
            return "Error"
        
    def on_close(self, event=None):  # 이벤트 핸들러에 맞게 인자 수정
        print("Closing application and saving data...")
        self.save_emotion_data()   
        self.vid.release()  # 카메라 해제
        self.window.destroy()  # 윈도우 종료       

    # 감정의 빈도 계산
    def get_emotion_frequencies(self):
        emotion_frequencies = Counter(emotion for emotion, _ in self.emotion_scores)
        return emotion_frequencies
    
    def update(self):
        ret, frame = self.vid.read()
        if ret:
            self.display_frame(frame)
            self.window.after(1, self.update)
        
    def print_emotion_data(self):
        print(self.emotions_df)      
        
    def display_frame(self, frame):
        try:
            frame = cv2.resize(frame, (640, 480))
            faces = self.face_cascade.detectMultiScale(frame, 1.1, 4)
            for (x, y, w, h) in faces:
                # 얼굴 크기가 충분히 큰지 확인
                if w >= 100 and h >= 100:
                    face_img = frame[y:y+h, x:x+w]
                    emotion = self.predict_emotion(face_img)
                    cv2.rectangle(frame, (x, y), (x+w, y+h), (0, 255, 0), 2)
                    cv2.putText(frame, emotion, (x, y-10), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (36,255,12), 2)
                else:
                    print("Detected face is too small")
            
            cv2image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGBA)
            self.img = Image.fromarray(cv2image)
            self.imgtk = ImageTk.PhotoImage(image=self.img)
            self.canvas.imgtk = self.imgtk
            self.canvas.configure(image=self.imgtk)
        except Exception as e:
            print(f"display_frame에서 오류 발생: {e}")

            

    def save_emotion_data(self):
        self.emotions_df.to_csv("emotion_data.csv", index=False)
        print("Emotion data saved to 'emotion_data.csv'.")   

# 메인 부분
if __name__ == '__main__':
    root = tk.Tk()
    model = keras.models.load_model('emotion_model.h5')
    app =  FaceRecognitionApp(root, "Face Recognition", model)
# Out:
# 1/1 [==============================] - 0s 80ms/step
# Surprise
# 1/1 [==============================] - 0s 17ms/step
# Angry
# 1/1 [==============================] - 0s 19ms/step
# Angry
# 1/1 [==============================] - 0s 17ms/step
# Sad
# 1/1 [==============================] - 0s 16ms/step
# Angry
# 1/1 [==============================] - 0s 16ms/step
# Angry
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 18ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 17ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 17ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 20ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 17ms/step
# Confident
# 1/1 [==============================] - 0s 15ms/step
# Confident
# 1/1 [==============================] - 0s 17ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 15ms/step
# Confident
# 1/1 [==============================] - 0s 17ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 15ms/step
# Surprise
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 15ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 17ms/step
# Confident
# 1/1 [==============================] - 0s 15ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Happy
# 1/1 [==============================] - 0s 16ms/step
# Sad
# 1/1 [==============================] - 0s 16ms/step
# Happy
# 1/1 [==============================] - 0s 17ms/step
# Confident
# 1/1 [==============================] - 0s 17ms/step
# Happy
# Detected face is too small
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 17ms/step
# Confident
# 1/1 [==============================] - 0s 17ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 17ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 15ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Sad
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 15ms/step
# Sad
# 1/1 [==============================] - 0s 15ms/step
# Confident
# 1/1 [==============================] - 0s 15ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 17ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Angry
# 1/1 [==============================] - 0s 16ms/step
# Angry
# 1/1 [==============================] - 0s 17ms/step
# Angry
# 1/1 [==============================] - 0s 16ms/step
# Angry
# 1/1 [==============================] - 0s 16ms/step
# Surprise
# 1/1 [==============================] - 0s 16ms/step
# Angry
# 1/1 [==============================] - 0s 17ms/step
# Angry
# 1/1 [==============================] - 0s 16ms/step
# Angry
# 1/1 [==============================] - 0s 16ms/step
# Angry
# 1/1 [==============================] - 0s 16ms/step
# Angry
# 1/1 [==============================] - 0s 16ms/step
# Angry
# 1/1 [==============================] - 0s 16ms/step
# Angry
# 1/1 [==============================] - 0s 16ms/step
# Angry
# 1/1 [==============================] - 0s 16ms/step
# Angry
# 1/1 [==============================] - 0s 17ms/step
# Angry
# 1/1 [==============================] - 0s 16ms/step
# Angry
# 1/1 [==============================] - 0s 16ms/step
# Angry
# 1/1 [==============================] - 0s 16ms/step
# Angry
# 1/1 [==============================] - 0s 15ms/step
# Angry
# 1/1 [==============================] - 0s 17ms/step
# Angry
# 1/1 [==============================] - 0s 16ms/step
# Angry
# 1/1 [==============================] - 0s 15ms/step
# Angry
# Detected face is too small
# 1/1 [==============================] - 0s 16ms/step
# Angry
# 1/1 [==============================] - 0s 16ms/step
# Angry
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# 1/1 [==============================] - 0s 16ms/step
# Angry
# 1/1 [==============================] - 0s 15ms/step
# Angry
# 1/1 [==============================] - 0s 15ms/step
# Surprise
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Surprise
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 15ms/step
# Surprise
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Happy
# 1/1 [==============================] - 0s 16ms/step
# Surprise
# 1/1 [==============================] - 0s 16ms/step
# Surprise
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Happy
# 1/1 [==============================] - 0s 16ms/step
# Surprise
# 1/1 [==============================] - 0s 16ms/step
# Surprise
# 1/1 [==============================] - 0s 16ms/step
# Surprise
# 1/1 [==============================] - 0s 15ms/step
# Surprise
# 1/1 [==============================] - 0s 16ms/step
# Surprise
# 1/1 [==============================] - 0s 16ms/step
# Surprise
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 15ms/step
# Happy
# 1/1 [==============================] - 0s 16ms/step
# Happy
# 1/1 [==============================] - 0s 16ms/step
# Surprise
# 1/1 [==============================] - 0s 16ms/step
# Confident
# Detected face is too small
# Detected face is too small
# 1/1 [==============================] - 0s 15ms/step
# Happy
# 1/1 [==============================] - 0s 17ms/step
# Surprise
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Happy
# 1/1 [==============================] - 0s 15ms/step
# Surprise
# 1/1 [==============================] - 0s 16ms/step
# Happy
# 1/1 [==============================] - 0s 16ms/step
# Happy
# 1/1 [==============================] - 0s 17ms/step
# Sad
# 1/1 [==============================] - 0s 16ms/step
# Happy
# 1/1 [==============================] - 0s 16ms/step
# Sad
# 1/1 [==============================] - 0s 16ms/step
# Happy
# 1/1 [==============================] - 0s 15ms/step
# Surprise
# 1/1 [==============================] - 0s 15ms/step
# Surprise
# 1/1 [==============================] - 0s 16ms/step
# Happy
# 1/1 [==============================] - 0s 15ms/step
# Surprise
# 1/1 [==============================] - 0s 16ms/step
# Happy
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# 1/1 [==============================] - 0s 14ms/step
# Surprise
# Detected face is too small
# Detected face is too small
# 1/1 [==============================] - 0s 15ms/step
# Surprise
# 1/1 [==============================] - 0s 16ms/step
# Surprise
# 1/1 [==============================] - 0s 19ms/step
# Surprise
# 1/1 [==============================] - 0s 16ms/step
# Surprise
# 1/1 [==============================] - 0s 16ms/step
# Surprise
# Detected face is too small
# Detected face is too small
# 1/1 [==============================] - 0s 15ms/step
# Confident
# 1/1 [==============================] - 0s 15ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Angry
# 1/1 [==============================] - 0s 15ms/step
# Angry
# 1/1 [==============================] - 0s 15ms/step
# Happy
# 1/1 [==============================] - 0s 16ms/step
# Happy
# 1/1 [==============================] - 0s 16ms/step
# Happy
# 1/1 [==============================] - 0s 15ms/step
# Happy
# Detected face is too small
# 1/1 [==============================] - 0s 15ms/step
# Happy
# Detected face is too small
# 1/1 [==============================] - 0s 17ms/step
# Surprise
# 1/1 [==============================] - 0s 15ms/step
# Surprise
# 1/1 [==============================] - 0s 17ms/step
# Surprise
# 1/1 [==============================] - 0s 16ms/step
# Surprise
# 1/1 [==============================] - 0s 16ms/step
# Surprise
# 1/1 [==============================] - 0s 16ms/step
# Surprise
# 1/1 [==============================] - 0s 17ms/step
# Surprise
# 1/1 [==============================] - 0s 15ms/step
# Surprise
# 1/1 [==============================] - 0s 16ms/step
# Surprise
# 1/1 [==============================] - 0s 16ms/step
# Surprise
# 1/1 [==============================] - 0s 16ms/step
# Surprise
# 1/1 [==============================] - 0s 16ms/step
# Surprise
# 1/1 [==============================] - 0s 16ms/step
# Surprise
# 1/1 [==============================] - 0s 16ms/step
# Surprise
# 1/1 [==============================] - 0s 16ms/step
# Surprise
# 1/1 [==============================] - 0s 17ms/step
# Angry
# 1/1 [==============================] - 0s 16ms/step
# Happy
# 1/1 [==============================] - 0s 16ms/step
# Happy
# 1/1 [==============================] - 0s 15ms/step
# Happy
# 1/1 [==============================] - 0s 16ms/step
# Happy
# 1/1 [==============================] - 0s 17ms/step
# Happy
# 1/1 [==============================] - 0s 16ms/step
# Happy
# 1/1 [==============================] - 0s 16ms/step
# Happy
# 1/1 [==============================] - 0s 16ms/step
# Happy
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 17ms/step
# Confident
# 1/1 [==============================] - 0s 15ms/step
# Confident
# 1/1 [==============================] - 0s 15ms/step
# Happy
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 17ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Happy
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 15ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 15ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 15ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 17ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Happy
# 1/1 [==============================] - 0s 18ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Happy
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Happy
# 1/1 [==============================] - 0s 16ms/step
# Happy
# 1/1 [==============================] - 0s 17ms/step
# Confident
# 1/1 [==============================] - 0s 17ms/step
# Happy
# 1/1 [==============================] - 0s 16ms/step
# Happy
# 1/1 [==============================] - 0s 15ms/step
# Confident
# 1/1 [==============================] - 0s 17ms/step
# Happy
# 1/1 [==============================] - 0s 17ms/step
# Confident
# 1/1 [==============================] - 0s 15ms/step
# Happy
# 1/1 [==============================] - 0s 16ms/step
# Happy
# 1/1 [==============================] - 0s 16ms/step
# Surprise
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Surprise
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 15ms/step
# Happy
# 1/1 [==============================] - 0s 17ms/step
# Happy
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 15ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 17ms/step
# Confident
# 1/1 [==============================] - 0s 17ms/step
# Confident
# 1/1 [==============================] - 0s 15ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 15ms/step
# Confident
# 1/1 [==============================] - 0s 15ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 17ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Confident
# Detected face is too small
# 1/1 [==============================] - 0s 16ms/step
# Confident
# Detected face is too small
# 1/1 [==============================] - 0s 16ms/step
# Confident
# Detected face is too small
# 1/1 [==============================] - 0s 15ms/step
# Confident
# Detected face is too small
# 1/1 [==============================] - 0s 15ms/step
# Confident
# 1/1 [==============================] - 0s 17ms/step
# Confident
# 1/1 [==============================] - 0s 17ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 17ms/step
# Confident
# 1/1 [==============================] - 0s 15ms/step
# Confident
# 1/1 [==============================] - 0s 15ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 17ms/step
# Confident
# Detected face is too small
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 15ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Happy
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 15ms/step
# Happy
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 17ms/step
# Confident
# 1/1 [==============================] - 0s 15ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 15ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 15ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 15ms/step
# Confident
# 1/1 [==============================] - 0s 15ms/step
# Confident
# 1/1 [==============================] - 0s 15ms/step
# Sad
# 1/1 [==============================] - 0s 18ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 15ms/step
# Sad
# 1/1 [==============================] - 0s 17ms/step
# Confident
# 1/1 [==============================] - 0s 17ms/step
# Sad
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 15ms/step
# Sad
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Sad
# Detected face is too small
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 17ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Confident
# Detected face is too small
# 1/1 [==============================] - 0s 16ms/step
# Confident
# Detected face is too small
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Confident
# Detected face is too small
# 1/1 [==============================] - 0s 16ms/step
# Confident
# Detected face is too small
# 1/1 [==============================] - 0s 16ms/step
# Confident
# Detected face is too small
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Confident
# Detected face is too small
# 1/1 [==============================] - 0s 16ms/step
# Confident
# Detected face is too small
# 1/1 [==============================] - 0s 16ms/step
# Confident
# Detected face is too small
# 1/1 [==============================] - 0s 15ms/step
# Confident
# 1/1 [==============================] - 0s 15ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Happy
# 1/1 [==============================] - 0s 15ms/step
# Happy
# 1/1 [==============================] - 0s 16ms/step
# Happy
# 1/1 [==============================] - 0s 15ms/step
# Happy
# 1/1 [==============================] - 0s 16ms/step
# Happy
# 1/1 [==============================] - 0s 16ms/step
# Happy
# 1/1 [==============================] - 0s 16ms/step
# Happy
# 1/1 [==============================] - 0s 16ms/step
# Happy
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Surprise
# Detected face is too small
# Detected face is too small
# 1/1 [==============================] - 0s 17ms/step
# Confident
# 1/1 [==============================] - 0s 17ms/step
# Happy
# 1/1 [==============================] - 0s 16ms/step
# Happy
# 1/1 [==============================] - 0s 16ms/step
# Happy
# 1/1 [==============================] - 0s 17ms/step
# Happy
# 1/1 [==============================] - 0s 17ms/step
# Happy
# 1/1 [==============================] - 0s 16ms/step
# Happy
# 1/1 [==============================] - 0s 16ms/step
# Happy
# Detected face is too small
# 1/1 [==============================] - 0s 16ms/step
# Happy
# 1/1 [==============================] - 0s 16ms/step
# Happy
# 1/1 [==============================] - 0s 16ms/step
# Happy
# 1/1 [==============================] - 0s 17ms/step
# Happy
# 1/1 [==============================] - 0s 16ms/step
# Happy
# 1/1 [==============================] - 0s 16ms/step
# Sad
# 1/1 [==============================] - 0s 18ms/step
# Happy
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Sad
# 1/1 [==============================] - 0s 16ms/step
# Sad
# 1/1 [==============================] - 0s 15ms/step
# Sad
# 1/1 [==============================] - 0s 15ms/step
# Sad
# 1/1 [==============================] - 0s 16ms/step
# Sad
# 1/1 [==============================] - 0s 16ms/step
# Sad
# 1/1 [==============================] - 0s 15ms/step
# Sad
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Angry
# 1/1 [==============================] - 0s 17ms/step
# Angry
# 1/1 [==============================] - 0s 15ms/step
# Angry
# 1/1 [==============================] - 0s 15ms/step
# Angry
# 1/1 [==============================] - 0s 16ms/step
# Angry
# 1/1 [==============================] - 0s 16ms/step
# Angry
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 15ms/step
# Confident
# 1/1 [==============================] - 0s 17ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 17ms/step
# Angry
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 15ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Angry
# 1/1 [==============================] - 0s 17ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Angry
# 1/1 [==============================] - 0s 15ms/step
# Angry
# 1/1 [==============================] - 0s 15ms/step
# Angry
# 1/1 [==============================] - 0s 16ms/step
# Angry
# 1/1 [==============================] - 0s 16ms/step
# Angry
# 1/1 [==============================] - 0s 16ms/step
# Angry
# 1/1 [==============================] - 0s 16ms/step
# Angry
# 1/1 [==============================] - 0s 16ms/step
# Angry
# 1/1 [==============================] - 0s 16ms/step
# Angry
# 1/1 [==============================] - 0s 16ms/step
# Angry
# 1/1 [==============================] - 0s 16ms/step
# Angry
# 1/1 [==============================] - 0s 16ms/step
# Angry
# 1/1 [==============================] - 0s 16ms/step
# Angry
# 1/1 [==============================] - 0s 15ms/step
# Angry
# 1/1 [==============================] - 0s 16ms/step
# Angry
# 1/1 [==============================] - 0s 16ms/step
# Angry
# 1/1 [==============================] - 0s 16ms/step
# Angry
# 1/1 [==============================] - 0s 16ms/step
# Angry
# 1/1 [==============================] - 0s 15ms/step
# Angry
# 1/1 [==============================] - 0s 16ms/step
# Angry
# 1/1 [==============================] - 0s 16ms/step
# Angry
# 1/1 [==============================] - 0s 16ms/step
# Surprise
# 1/1 [==============================] - 0s 16ms/step
# Angry
# 1/1 [==============================] - 0s 16ms/step
# Angry
# 1/1 [==============================] - 0s 16ms/step
# Angry
# 1/1 [==============================] - 0s 16ms/step
# Angry
# 1/1 [==============================] - 0s 16ms/step
# Angry
# 1/1 [==============================] - 0s 16ms/step
# Angry
# 1/1 [==============================] - 0s 16ms/step
# Angry
# 1/1 [==============================] - 0s 15ms/step
# Angry
# 1/1 [==============================] - 0s 15ms/step
# Angry
# 1/1 [==============================] - 0s 17ms/step
# Angry
# 1/1 [==============================] - 0s 16ms/step
# Happy
# Detected face is too small
# 1/1 [==============================] - 0s 16ms/step
# Happy
# 1/1 [==============================] - 0s 16ms/step
# Happy
# 1/1 [==============================] - 0s 16ms/step
# Happy
# 1/1 [==============================] - 0s 15ms/step
# Happy
# 1/1 [==============================] - 0s 16ms/step
# Happy
# 1/1 [==============================] - 0s 16ms/step
# Happy
# 1/1 [==============================] - 0s 16ms/step
# Happy
# 1/1 [==============================] - 0s 15ms/step
# Happy
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# 1/1 [==============================] - 0s 15ms/step
# Happy
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# 1/1 [==============================] - 0s 14ms/step
# Happy
# 1/1 [==============================] - 0s 16ms/step
# Sad
# Detected face is too small
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Happy
# 1/1 [==============================] - 0s 16ms/step
# Happy
# Detected face is too small
# 1/1 [==============================] - 0s 16ms/step
# Happy
# Detected face is too small
# 1/1 [==============================] - 0s 16ms/step
# Happy
# Detected face is too small
# 1/1 [==============================] - 0s 15ms/step
# Happy
# 1/1 [==============================] - 0s 17ms/step
# Happy
# 1/1 [==============================] - 0s 16ms/step
# Happy
# 1/1 [==============================] - 0s 16ms/step
# Happy
# 1/1 [==============================] - 0s 15ms/step
# Happy
# 1/1 [==============================] - 0s 18ms/step
# Happy
# 1/1 [==============================] - 0s 16ms/step
# Happy
# 1/1 [==============================] - 0s 16ms/step
# Happy
# 1/1 [==============================] - 0s 17ms/step
# Happy
# 1/1 [==============================] - 0s 17ms/step
# Happy
# Detected face is too small
# 1/1 [==============================] - 0s 17ms/step
# Happy
# 1/1 [==============================] - 0s 15ms/step
# Angry
# 1/1 [==============================] - 0s 16ms/step
# Angry
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# 1/1 [==============================] - 0s 15ms/step
# Happy
# Detected face is too small
# Detected face is too small
# 1/1 [==============================] - 0s 16ms/step
# Angry
# Detected face is too small
# 1/1 [==============================] - 0s 15ms/step
# Angry
# Detected face is too small
# 1/1 [==============================] - 0s 16ms/step
# Angry
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# 1/1 [==============================] - 0s 15ms/step
# Happy
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# 1/1 [==============================] - 0s 15ms/step
# Happy
# 1/1 [==============================] - 0s 16ms/step
# Happy
# 1/1 [==============================] - 0s 19ms/step
# Happy
# Detected face is too small
# 1/1 [==============================] - 0s 16ms/step
# Happy
# 1/1 [==============================] - 0s 16ms/step
# Happy
# 1/1 [==============================] - 0s 16ms/step
# Happy
# 1/1 [==============================] - 0s 16ms/step
# Happy
# Detected face is too small
# 1/1 [==============================] - 0s 15ms/step
# Happy
# 1/1 [==============================] - 0s 15ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Happy
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 17ms/step
# Happy
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Happy
# 1/1 [==============================] - 0s 15ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Angry
# 1/1 [==============================] - 0s 15ms/step
# Happy
# 1/1 [==============================] - 0s 16ms/step
# Happy
# 1/1 [==============================] - 0s 17ms/step
# Confident
# 1/1 [==============================] - 0s 15ms/step
# Happy
# 1/1 [==============================] - 0s 15ms/step
# Angry
# 1/1 [==============================] - 0s 16ms/step
# Happy
# 1/1 [==============================] - 0s 16ms/step
# Angry
# 1/1 [==============================] - 0s 16ms/step
# Sad
# 1/1 [==============================] - 0s 17ms/step
# Happy
# 1/1 [==============================] - 0s 18ms/step
# Angry
# 1/1 [==============================] - 0s 16ms/step
# Happy
# 1/1 [==============================] - 0s 16ms/step
# Happy
# 1/1 [==============================] - 0s 16ms/step
# Happy
# 1/1 [==============================] - 0s 16ms/step
# Happy
# Detected face is too small
# 1/1 [==============================] - 0s 16ms/step
# Happy
# 1/1 [==============================] - 0s 16ms/step
# Happy
# 1/1 [==============================] - 0s 17ms/step
# Happy
# 1/1 [==============================] - 0s 16ms/step
# Happy
# 1/1 [==============================] - 0s 17ms/step
# Happy
# 1/1 [==============================] - 0s 15ms/step
# Happy
# 1/1 [==============================] - 0s 16ms/step
# Happy
# 1/1 [==============================] - 0s 16ms/step
# Happy
# 1/1 [==============================] - 0s 15ms/step
# Happy
# 1/1 [==============================] - 0s 15ms/step
# Happy
# 1/1 [==============================] - 0s 16ms/step
# Happy
# 1/1 [==============================] - 0s 16ms/step
# Happy
# 1/1 [==============================] - 0s 16ms/step
# Sad
# 1/1 [==============================] - 0s 16ms/step
# Sad
# 1/1 [==============================] - 0s 16ms/step
# Surprise
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# 1/1 [==============================] - 0s 15ms/step
# Happy
# 1/1 [==============================] - 0s 15ms/step
# Happy
# 1/1 [==============================] - 0s 16ms/step
# Happy
# 1/1 [==============================] - 0s 16ms/step
# Happy
# Detected face is too small
# 1/1 [==============================] - 0s 15ms/step
# Happy
# 1/1 [==============================] - 0s 15ms/step
# Happy
# 1/1 [==============================] - 0s 16ms/step
# Happy
# 1/1 [==============================] - 0s 15ms/step
# Happy
# 1/1 [==============================] - 0s 16ms/step
# Happy
# 1/1 [==============================] - 0s 16ms/step
# Happy
# 1/1 [==============================] - 0s 16ms/step
# Happy
# 1/1 [==============================] - 0s 16ms/step
# Angry
# 1/1 [==============================] - 0s 15ms/step
# Angry
# Detected face is too small
# 1/1 [==============================] - 0s 15ms/step
# Happy
# Detected face is too small
# 1/1 [==============================] - 0s 16ms/step
# Happy
# Detected face is too small
# 1/1 [==============================] - 0s 16ms/step
# Sad
# 1/1 [==============================] - 0s 16ms/step
# Happy
# 1/1 [==============================] - 0s 16ms/step
# Happy
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Happy
# 1/1 [==============================] - 0s 16ms/step
# Happy
# Detected face is too small
# 1/1 [==============================] - 0s 16ms/step
# Happy
# 1/1 [==============================] - 0s 16ms/step
# Happy
# 1/1 [==============================] - 0s 16ms/step
# Happy
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 15ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 15ms/step
# Confident
# 1/1 [==============================] - 0s 17ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 15ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 17ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 15ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 15ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 15ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 15ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 15ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 15ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 15ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 15ms/step
# Confident
# 1/1 [==============================] - 0s 17ms/step
# Confident
# 1/1 [==============================] - 0s 15ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 15ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Angry
# Detected face is too small
# 1/1 [==============================] - 0s 16ms/step
# Confident
# Detected face is too small
# 1/1 [==============================] - 0s 16ms/step
# Confident
# Detected face is too small
# 1/1 [==============================] - 0s 15ms/step
# Confident
# Detected face is too small
# 1/1 [==============================] - 0s 15ms/step
# Angry
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 15ms/step
# Confident
# 1/1 [==============================] - 0s 15ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 15ms/step
# Confident
# 1/1 [==============================] - 0s 15ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 15ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Confident
# Detected face is too small
# 1/1 [==============================] - 0s 16ms/step
# Confident
# Detected face is too small
# 1/1 [==============================] - 0s 16ms/step
# Confident
# Detected face is too small
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 15ms/step
# Confident
# 1/1 [==============================] - 0s 15ms/step
# Confident
# 1/1 [==============================] - 0s 17ms/step
# Confident
# 1/1 [==============================] - 0s 15ms/step
# Confident
# 1/1 [==============================] - 0s 15ms/step
# Angry
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 15ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 15ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Neutral
# 1/1 [==============================] - 0s 16ms/step
# Neutral
# 1/1 [==============================] - 0s 15ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 15ms/step
# Confident
# 1/1 [==============================] - 0s 15ms/step
# Confident
# 1/1 [==============================] - 0s 15ms/step
# Confident
# Detected face is too small
# 1/1 [==============================] - 0s 16ms/step
# Confident
# Detected face is too small
# 1/1 [==============================] - 0s 16ms/step
# Confident
# Detected face is too small
# 1/1 [==============================] - 0s 16ms/step
# Confident
# Detected face is too small
# 1/1 [==============================] - 0s 17ms/step
# Confident
# Detected face is too small
# 1/1 [==============================] - 0s 16ms/step
# Confident
# Detected face is too small
# 1/1 [==============================] - 0s 16ms/step
# Angry
# Detected face is too small
# 1/1 [==============================] - 0s 16ms/step
# Angry
# Detected face is too small
# 1/1 [==============================] - 0s 16ms/step
# Angry
# Detected face is too small
# 1/1 [==============================] - 0s 17ms/step
# Neutral
# Detected face is too small
# 1/1 [==============================] - 0s 16ms/step
# Neutral
# 1/1 [==============================] - 0s 17ms/step
# Angry
# 1/1 [==============================] - 0s 15ms/step
# Angry
# 1/1 [==============================] - 0s 15ms/step
# Angry
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 15ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 15ms/step
# Confident
# 1/1 [==============================] - 0s 15ms/step
# Confident
# 1/1 [==============================] - 0s 17ms/step
# Confident
# 1/1 [==============================] - 0s 15ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Confident
# Detected face is too small
# 1/1 [==============================] - 0s 16ms/step
# Confident
# Detected face is too small
# 1/1 [==============================] - 0s 16ms/step
# Confident
# Detected face is too small
# 1/1 [==============================] - 0s 17ms/step
# Confident
# Detected face is too small
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Angry
# 1/1 [==============================] - 0s 16ms/step
# Angry
# Detected face is too small
# 1/1 [==============================] - 0s 15ms/step
# Angry
# Detected face is too small
# 1/1 [==============================] - 0s 16ms/step
# Angry
# Detected face is too small
# 1/1 [==============================] - 0s 16ms/step
# Confident
# Detected face is too small
# 1/1 [==============================] - 0s 16ms/step
# Confident
# Detected face is too small
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Confident
# Detected face is too small
# 1/1 [==============================] - 0s 17ms/step
# Confident
# Detected face is too small
# 1/1 [==============================] - 0s 16ms/step
# Confident
# Detected face is too small
# 1/1 [==============================] - 0s 16ms/step
# Confident
# Detected face is too small
# 1/1 [==============================] - 0s 15ms/step
# Confident
# Detected face is too small
# 1/1 [==============================] - 0s 15ms/step
# Confident
# 1/1 [==============================] - 0s 15ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 15ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 15ms/step
# Confident
# 1/1 [==============================] - 0s 15ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Happy
# 1/1 [==============================] - 0s 16ms/step
# Happy
# 1/1 [==============================] - 0s 16ms/step
# Neutral
# 1/1 [==============================] - 0s 15ms/step
# Neutral
# 1/1 [==============================] - 0s 16ms/step
# Happy
# 1/1 [==============================] - 0s 16ms/step
# Happy
# 1/1 [==============================] - 0s 16ms/step
# Confident
# Detected face is too small
# 1/1 [==============================] - 0s 15ms/step
# Neutral
# Detected face is too small
# 1/1 [==============================] - 0s 16ms/step
# Happy
# 1/1 [==============================] - 0s 16ms/step
# Happy
# 1/1 [==============================] - 0s 16ms/step
# Confident
# Detected face is too small
# 1/1 [==============================] - 0s 16ms/step
# Surprise
# Detected face is too small
# Detected face is too small
# 1/1 [==============================] - 0s 17ms/step
# Surprise
# Detected face is too small
# 1/1 [==============================] - 0s 16ms/step
# Surprise
# Detected face is too small
# 1/1 [==============================] - 0s 15ms/step
# Surprise
# 1/1 [==============================] - 0s 16ms/step
# Happy
# 1/1 [==============================] - 0s 16ms/step
# Surprise
# 1/1 [==============================] - 0s 16ms/step
# Happy
# 1/1 [==============================] - 0s 15ms/step
# Surprise
# 1/1 [==============================] - 0s 16ms/step
# Happy
# 1/1 [==============================] - 0s 16ms/step
# Happy
# 1/1 [==============================] - 0s 16ms/step
# Happy
# 1/1 [==============================] - 0s 16ms/step
# Happy
# 1/1 [==============================] - 0s 16ms/step
# Sad
# 1/1 [==============================] - 0s 16ms/step
# Happy
# 1/1 [==============================] - 0s 16ms/step
# Happy
# 1/1 [==============================] - 0s 17ms/step
# Surprise
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Surprise
# 1/1 [==============================] - 0s 16ms/step
# Happy
# 1/1 [==============================] - 0s 16ms/step
# Surprise
# 1/1 [==============================] - 0s 17ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Surprise
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Surprise
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 15ms/step
# Happy
# 1/1 [==============================] - 0s 17ms/step
# Happy
# 1/1 [==============================] - 0s 16ms/step
# Happy
# 1/1 [==============================] - 0s 15ms/step
# Happy
# 1/1 [==============================] - 0s 16ms/step
# Angry
# 1/1 [==============================] - 0s 17ms/step
# Angry
# 1/1 [==============================] - 0s 16ms/step
# Angry
# 1/1 [==============================] - 0s 17ms/step
# Angry
# 1/1 [==============================] - 0s 16ms/step
# Angry
# 1/1 [==============================] - 0s 16ms/step
# Angry
# 1/1 [==============================] - 0s 16ms/step
# Angry
# 1/1 [==============================] - 0s 16ms/step
# Angry
# 1/1 [==============================] - 0s 17ms/step
# Angry
# 1/1 [==============================] - 0s 15ms/step
# Angry
# 1/1 [==============================] - 0s 16ms/step
# Angry
# 1/1 [==============================] - 0s 16ms/step
# Angry
# 1/1 [==============================] - 0s 17ms/step
# Angry
# 1/1 [==============================] - 0s 16ms/step
# Angry
# 1/1 [==============================] - 0s 18ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Surprise
# 1/1 [==============================] - 0s 16ms/step
# Angry
# 1/1 [==============================] - 0s 15ms/step
# Angry
# 1/1 [==============================] - 0s 15ms/step
# Angry
# 1/1 [==============================] - 0s 16ms/step
# Angry
# 1/1 [==============================] - 0s 16ms/step
# Angry
# 1/1 [==============================] - 0s 16ms/step
# Angry
# 1/1 [==============================] - 0s 16ms/step
# Angry
# 1/1 [==============================] - 0s 16ms/step
# Angry
# 1/1 [==============================] - 0s 16ms/step
# Angry
# 1/1 [==============================] - 0s 16ms/step
# Angry
# 1/1 [==============================] - 0s 15ms/step
# Angry
# 1/1 [==============================] - 0s 16ms/step
# Angry
# 1/1 [==============================] - 0s 16ms/step
# Angry
# 1/1 [==============================] - 0s 16ms/step
# Sad
# 1/1 [==============================] - 0s 16ms/step
# Surprise
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 15ms/step
# Angry
# 1/1 [==============================] - 0s 16ms/step
# Surprise
# 1/1 [==============================] - 0s 15ms/step
# Angry
# 1/1 [==============================] - 0s 15ms/step
# Surprise
# 1/1 [==============================] - 0s 16ms/step
# Angry
# 1/1 [==============================] - 0s 16ms/step
# Surprise
# 1/1 [==============================] - 0s 16ms/step
# Sad
# 1/1 [==============================] - 0s 16ms/step
# Surprise
# 1/1 [==============================] - 0s 15ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Surprise
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Surprise
# 1/1 [==============================] - 0s 15ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Surprise
# 1/1 [==============================] - 0s 16ms/step
# Angry
# 1/1 [==============================] - 0s 16ms/step
# Surprise
# 1/1 [==============================] - 0s 15ms/step
# Angry
# 1/1 [==============================] - 0s 15ms/step
# Surprise
# 1/1 [==============================] - 0s 16ms/step
# Angry
# 1/1 [==============================] - 0s 15ms/step
# Surprise
# 1/1 [==============================] - 0s 16ms/step
# Angry
# 1/1 [==============================] - 0s 15ms/step
# Surprise
# 1/1 [==============================] - 0s 16ms/step
# Angry
# 1/1 [==============================] - 0s 15ms/step
# Surprise
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Happy
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 15ms/step
# Confident
# 1/1 [==============================] - 0s 15ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Happy
# 1/1 [==============================] - 0s 16ms/step
# Happy
# 1/1 [==============================] - 0s 16ms/step
# Sad
# 1/1 [==============================] - 0s 16ms/step
# Angry
# 1/1 [==============================] - 0s 16ms/step
# Angry
# 1/1 [==============================] - 0s 16ms/step
# Angry
# 1/1 [==============================] - 0s 17ms/step
# Angry
# 1/1 [==============================] - 0s 16ms/step
# Angry
# Detected face is too small
# 1/1 [==============================] - 0s 16ms/step
# Happy
# Detected face is too small
# 1/1 [==============================] - 0s 16ms/step
# Happy
# 1/1 [==============================] - 0s 16ms/step
# Angry
# 1/1 [==============================] - 0s 16ms/step
# Angry
# 1/1 [==============================] - 0s 16ms/step
# Angry
# 1/1 [==============================] - 0s 17ms/step
# Surprise
# 1/1 [==============================] - 0s 16ms/step
# Angry
# 1/1 [==============================] - 0s 16ms/step
# Surprise
# Detected face is too small
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 18ms/step
# Surprise
# Detected face is too small
# 1/1 [==============================] - 0s 16ms/step
# Surprise
# Detected face is too small
# 1/1 [==============================] - 0s 16ms/step
# Happy
# 1/1 [==============================] - 0s 15ms/step
# Surprise
# 1/1 [==============================] - 0s 16ms/step
# Happy
# Detected face is too small
# 1/1 [==============================] - 0s 15ms/step
# Confident
# 1/1 [==============================] - 0s 15ms/step
# Surprise
# Detected face is too small
# 1/1 [==============================] - 0s 16ms/step
# Happy
# 1/1 [==============================] - 0s 16ms/step
# Happy
# 1/1 [==============================] - 0s 16ms/step
# Happy
# 1/1 [==============================] - 0s 17ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Surprise
# Detected face is too small
# 1/1 [==============================] - 0s 15ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Surprise
# 1/1 [==============================] - 0s 17ms/step
# Confident
# 1/1 [==============================] - 0s 15ms/step
# Surprise
# 1/1 [==============================] - 0s 17ms/step
# Surprise
# 1/1 [==============================] - 0s 16ms/step
# Happy
# 1/1 [==============================] - 0s 16ms/step
# Surprise
# 1/1 [==============================] - 0s 15ms/step
# Happy
# 1/1 [==============================] - 0s 17ms/step
# Happy
# 1/1 [==============================] - 0s 16ms/step
# Happy
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# Detected face is too small
# 1/1 [==============================] - 0s 16ms/step
# Surprise
# 1/1 [==============================] - 0s 15ms/step
# Happy
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Neutral
# Detected face is too small
# Detected face is too small
# Detected face is too small
# 1/1 [==============================] - 0s 16ms/step
# Surprise
# 1/1 [==============================] - 0s 15ms/step
# Surprise
# Detected face is too small
# 1/1 [==============================] - 0s 17ms/step
# Happy
# 1/1 [==============================] - 0s 16ms/step
# Happy
# 1/1 [==============================] - 0s 15ms/step
# Happy
# 1/1 [==============================] - 0s 15ms/step
# Happy
# 1/1 [==============================] - 0s 17ms/step
# Happy
# 1/1 [==============================] - 0s 15ms/step
# Happy
# 1/1 [==============================] - 0s 16ms/step
# Happy
# 1/1 [==============================] - 0s 16ms/step
# Happy
# 1/1 [==============================] - 0s 16ms/step
# Happy
# 1/1 [==============================] - 0s 17ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Happy
# 1/1 [==============================] - 0s 16ms/step
# Sad
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 15ms/step
# Happy
# 1/1 [==============================] - 0s 16ms/step
# Surprise
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Happy
# 1/1 [==============================] - 0s 16ms/step
# Surprise
# 1/1 [==============================] - 0s 17ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Surprise
# 1/1 [==============================] - 0s 16ms/step
# Happy
# 1/1 [==============================] - 0s 16ms/step
# Happy
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Happy
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 15ms/step
# Happy
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 15ms/step
# Happy
# 1/1 [==============================] - 0s 15ms/step
# Happy
# 1/1 [==============================] - 0s 15ms/step
# Happy
# 1/1 [==============================] - 0s 16ms/step
# Happy
# 1/1 [==============================] - 0s 16ms/step
# Happy
# 1/1 [==============================] - 0s 15ms/step
# Happy
# 1/1 [==============================] - 0s 15ms/step
# Happy
# 1/1 [==============================] - 0s 15ms/step
# Happy
# 1/1 [==============================] - 0s 17ms/step
# Happy
# 1/1 [==============================] - 0s 16ms/step
# Happy
# 1/1 [==============================] - 0s 17ms/step
# Confident
# 1/1 [==============================] - 0s 18ms/step
# Happy
# 1/1 [==============================] - 0s 17ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Happy
# 1/1 [==============================] - 0s 17ms/step
# Happy
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Happy
# 1/1 [==============================] - 0s 17ms/step
# Confident
# 1/1 [==============================] - 0s 17ms/step
# Surprise
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 17ms/step
# Confident
# 1/1 [==============================] - 0s 15ms/step
# Confident
# 1/1 [==============================] - 0s 15ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 15ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Surprise
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 17ms/step
# Confident
# 1/1 [==============================] - 0s 15ms/step
# Confident
# 1/1 [==============================] - 0s 15ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Happy
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 17ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 15ms/step
# Confident
# 1/1 [==============================] - 0s 17ms/step
# Angry
# 1/1 [==============================] - 0s 17ms/step
# Confident
# 1/1 [==============================] - 0s 16ms/step
# Confident
# 1/1 [==============================] - 0s 17ms/step
# Angry
